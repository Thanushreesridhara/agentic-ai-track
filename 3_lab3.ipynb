# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("twin/Gurukarthik_CV.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
# Guru Prabhakar
# Eulenbaumstr. 289, 44801 Bochum, Germany
# +4917666990180|bpgurukarthik@gmail.com|LinkedIn: linkedin.com/in/gurukarthikboluguddeprabhakar
# Summary
# Release Engineer with over 4 years of experience in connected systems, CI/CD pipelines, cloud platforms, and
# software release management. Strong focus on automation, secure software delivery, and distributed system testing.
# Interested in applying AI driven approaches and security testing methods to enhance verification pipelines and
# software quality in automotive compute platforms.
# Technical Skills
# Operating Systems: Windows, Linux|Programming & Scripting: Python, PowerShell, Bash, Groovy|Test
# Automation & System Testing: Pytest, Robot Framework, Hardware-in-the-Loop (HiL), Vector CANoe,
# Android Debug Bridge (adb), Trace & Log Analysis|Automotive Networks & Protocols: CAN/CAN-FD,
# Automotive Ethernet, VW Body Application Protocol (BAP)|Digital Key & Platform: CCC Mobile Device
# Key (MDK), MQB evo, Connectivity Module (ConMod)|Vehicle–Cloud Integration: MQTT, REST/HTTP
# APIs, TCP/IP|Security: TLS/mTLS, OAuth 2.0|CI/CD, DevSecOps & Release Management: Jenkins,
# Azure Pipelines, GitHub/Bitbucket, GitHub Actions, Azure DevOps, Shift-Left Security, SAST, Key Vault,
# Container Scanning, JFrog Artifactory|Cloud, Containers & Infrastructure: Docker, Kubernetes/AKS,
# Infrastructure as Code (IaC) with Terraform, Azure Resource Manager (ARM)|Monitoring & Observability:
# Prometheus, Grafana|AI-Assisted Testing & Development: GitHub Copilot, M365 Copilot, Claude,
# Generative AI for Testing|Project & Collaboration Tools: Jira (test plans & dashboards), Confluence
# Experience
# Volkswagen Infotainment GmbH10/2024 - Present
# System Integration, Test and Release Engineer Bochum, Germany
# • Defined and executed test strategies for end-to-end system validation. Led end-to-end testing of theMobile Device
# Key (MDK, smartphone-as-key)across the frontend, in-car modules, vehicle network, and backend; executed
# integrationtest runs with a98% pass rate.
# • Orchestrated Hardware-in-the-Loop (HiL) test environments, integrating software and vehicle hardware components for
# end-to-end validation.
# • Developed and maintainedPython based test automationfor system validation, health monitoring, and automated
# verification workflows, improving software quality and reducing manual test effort. Boosting automation test coverage
# from0% to 80%and reducing bench setup time by90%.
# • Developed and tested a Python based application for automated data transformation and validation, implementing unit
# and functional tests to ensure reliability across end-to-end software workflows.
# • Performed detailedtrace and log analysis(Vector CANoe logs, MQTT traffic), resolving more than18
# cross-component defectsthrough multi-source timestamp and log correlation.
# • Integrated automated test flows intoJenkins CI/CD pipelines(with nightly continuous testing) using CLI-driven
# execution flags, enabling unattended nightly system runs and faster feedback loops.
# • Orchestrated16 sprint-based releasesfor the Vehicle Integration connectivity stack, managing promotions from
# develop to master branches, multi-repository synchronization, build requests, and quality gates; delivered38
# artifacts/weekacross a 7-tier dependency chain.
# • DevelopedPythonbased automation tool for the release pipeline to streamline and standardize delivery preparation.
# • Managed sprint-based releases for the VI-ConMod software, handling Git branching/tagging, multi-repository
# synchronization, and artifact lifecycle in JFrog Artifactory with full traceability via Confluence checklists and Jira links.
# • Performed OSS compliance for the connectivity software stack. Improved compliance automation by enhancing
# Python-based OSS tooling, includingSPDX normalization, dual-directionBSD-2/3-Clause validator, license-file
# conformance checks, and a blacklist-candidate analyzer—reducing manual follow-up by40%.
# TeamViewer 05/2023 - 07/2024
# Software Release Engineer Working Student Goeppingen, Germany
# • Developed aPython-based automation toolto streamline the software release process, improving consistency and
# reducing manual effort.
# • Integrated release workflows withJiraandConfluencevia REST APIs and implementedunit testsfor 30+ release
# modules to ensure reliability.• Built cloud-basedCI/CD pipelineusing Azure DevOps and Azure CDN, cutting deployment time by50%and
# improving update availability.
# • Provisioned Azure infrastructure usingARM, implementing Infrastructure as Code (IaC) practices for repeatable and
# secure deployments.
# • Containerized release tools usingDockerto ensure environment consistency across development and deployment stages.
# • Optimized packaging and delivery workflows, achieving a40% reductionin software package size and a20%
# reductionin cloud operational costs.
# Bosch Thermotechnik / Bosch Home Comfort08/2022 - 01/2023
# DevOps Engineer Intern Wernau, Germany
# • Process Automation: Automated embedded software release tasks usingPythonand the BoschQG-CLItool,
# enabling consistent and repeatable artifact retrieval from multiple sources.
# • Developed Python scripts to integrate QG-CLI into aJenkins CI/CD pipeline, achieving a100% reduction in
# manual artifact fetch timeand improving release workflow reliability.
# • Enhanced internal tooling by identifying defects, reporting issues, and proposing improvements toQG-CLI, contributing
# to more stable release automation.
# Fraunhofer IOSB 08/2021 - 04/2022
# Research Assistant Ilmenau, Germany
# • Conducted comparative analysis of existing network simulators and simulation frameworks.
# • Simulation of different protocols for wireless communication using OMNeT++.
# • Utilized the data from firmware to create a simulation model using OMNeT++ that emulates the behavior of network
# nodes within the RTLS.
# • Implemented CI/CD pipeline to automatically test the software packages.
# GE Healthcare 07/2018 - 06/2019
# Manufacturing Process Trainee Engineer Bengaluru, India
# • Testing and Process Improvement: Implemented testing procedures for X-ray tube process equipment and supported
# product development.
# • Technical expert for (High kV Generator) product manufacturing processes, worked with value-stream team on daily and
# long-term projects impacting production, effectively participated in cross-functional kaizen events by learning and then
# utilising Lean concepts.
# • Supported development and evaluation of manufacturing processes for potential improvements and implementing change
# control procedures.
# Education
# Technical University of Ilmenau, Germany10/2019 - 07/2024
# Master of Science in Communications and Signal Processing Ilmenau, Germany
# Major Subjects: Communication Networks, Advanced Mobile Communication Networks, Cloud Computing.
# Collaborative research project: Cloud Security and DevSecOps Infrastructure for Machine Learning based IoT threat
# Mitigation. Automated DevSecOps CI/CD pipelines with integrated SAST and dependency, vulnerability scans to containerize
# and deploy the ML based threat detection service on Azure Kubernetes Service (AKS). Automated cloud resource provisioning
# using Terraform (IaC) and established observability with Prometheus and Grafana.
# Thesis: Investigation of Cloud-based Software Packaging and Release Management Systems at TeamViewer. Skills: Software
# Development Lifecycle, DevOps Practices, Microsoft Azure, Software Packaging and Deployment automation, CI/CD
# pipelines, Artifact Creation, Content Delivery Network (CDN).
# Visvesvaraya Technological University - RNSIT, India08/2014 - 06/2018
# Bachelor of Engineering in Electronics and Communication Bengaluru, India
# Thesis: Pest Control System using Raspberry pi
# Certifications
# Microsoft Certified: Azure Fundamentals|Atlassian Agile Project Management Professional Certificate|
# DevOps Professional Certificate by PagerDuty and LinkedIn|Docker Foundations Professional Certificate|
# Career Essentials in GitHub Professional Certificate|ISTQB Certified Tester Foundation Level (CTFL)|
# ISTQB Certified Tester – Testing with Generative AI (CT-GenAI) (Training Completed — Certification
# Examination Scheduled: Aug 2026)
# Language Skills
# German:A2 (Beginner)|English:Fluent (Professional Proficiency)

# %%
with open("twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Guru Karthik. I'm a Foodie.  I'm originally from Bengaluru, India, but I moved to Germany in 2019.
# I love all foods, particullarly Veg Food.Especially high protien and high fiber food.  I like all South Indian food that does not mean I hate North Indian food.
# I like sports. I like cricket, badminton, calisthenics and i love running.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's CV profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# My name is Guru Karthik. I'm a Foodie.  I'm originally from Bengaluru, India, but I moved to Germany in 2019.
# I love all foods, particullarly Veg Food.Especially high protien and high fiber food.  I like all South Indian food that does not mean I hate North Indian food.
# I like sports. I like cricket, badminton, calisthenics and i love running.
#
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's CV profile so that you can answer questions:
#
# Guru Prabhakar
# Eulenbaumstr. 289, 44801 Bochum, Germany
# +4917666990180|bpgurukarthik@gmail.com|LinkedIn: linkedin.com/in/gurukarthikboluguddeprabhakar
# Summary
# Release Engineer with over 4 years of experience in connected systems, CI/CD pipelines, cloud platforms, and
# software release management. Strong focus on automation, secure software delivery, and distributed system testing.
# Interested in applying AI driven approaches and security testing methods to enhance verification pipelines and
# software quality in automotive compute platforms.
# Technical Skills
# Operating Systems: Windows, Linux|Programming & Scripting: Python, PowerShell, Bash, Groovy|Test
# Automation & System Testing: Pytest, Robot Framework, Hardware-in-the-Loop (HiL), Vector CANoe,
# Android Debug Bridge (adb), Trace & Log Analysis|Automotive Networks & Protocols: CAN/CAN-FD,
# Automotive Ethernet, VW Body Application Protocol (BAP)|Digital Key & Platform: CCC Mobile Device
# Key (MDK), MQB evo, Connectivity Module (ConMod)|Vehicle–Cloud Integration: MQTT, REST/HTTP
# APIs, TCP/IP|Security: TLS/mTLS, OAuth 2.0|CI/CD, DevSecOps & Release Management: Jenkins,
# Azure Pipelines, GitHub/Bitbucket, GitHub Actions, Azure DevOps, Shift-Left Security, SAST, Key Vault,
# Container Scanning, JFrog Artifactory|Cloud, Containers & Infrastructure: Docker, Kubernetes/AKS,
# Infrastructure as Code (IaC) with Terraform, Azure Resource Manager (ARM)|Monitoring & Observability:
# Prometheus, Grafana|AI-Assisted Testing & Development: GitHub Copilot, M365 Copilot, Claude,
# Generative AI for Testing|Project & Collaboration Tools: Jira (test plans & dashboards), Confluence
# Experience
# Volkswagen Infotainment GmbH10/2024 - Present
# System Integration, Test and Release Engineer Bochum, Germany
# • Defined and executed test strategies for end-to-end system validation. Led end-to-end testing of theMobile Device
# Key (MDK, smartphone-as-key)across the frontend, in-car modules, vehicle network, and backend; executed
# integrationtest runs with a98% pass rate.
# • Orchestrated Hardware-in-the-Loop (HiL) test environments, integrating software and vehicle hardware components for
# end-to-end validation.
# • Developed and maintainedPython based test automationfor system validation, health monitoring, and automated
# verification workflows, improving software quality and reducing manual test effort. Boosting automation test coverage
# from0% to 80%and reducing bench setup time by90%.
# • Developed and tested a Python based application for automated data transformation and validation, implementing unit
# and functional tests to ensure reliability across end-to-end software workflows.
# • Performed detailedtrace and log analysis(Vector CANoe logs, MQTT traffic), resolving more than18
# cross-component defectsthrough multi-source timestamp and log correlation.
# • Integrated automated test flows intoJenkins CI/CD pipelines(with nightly continuous testing) using CLI-driven
# execution flags, enabling unattended nightly system runs and faster feedback loops.
# • Orchestrated16 sprint-based releasesfor the Vehicle Integration connectivity stack, managing promotions from
# develop to master branches, multi-repository synchronization, build requests, and quality gates; delivered38
# artifacts/weekacross a 7-tier dependency chain.
# • DevelopedPythonbased automation tool for the release pipeline to streamline and standardize delivery preparation.
# • Managed sprint-based releases for the VI-ConMod software, handling Git branching/tagging, multi-repository
# synchronization, and artifact lifecycle in JFrog Artifactory with full traceability via Confluence checklists and Jira links.
# • Performed OSS compliance for the connectivity software stack. Improved compliance automation by enhancing
# Python-based OSS tooling, includingSPDX normalization, dual-directionBSD-2/3-Clause validator, license-file
# conformance checks, and a blacklist-candidate analyzer—reducing manual follow-up by40%.
# TeamViewer 05/2023 - 07/2024
# Software Release Engineer Working Student Goeppingen, Germany
# • Developed aPython-based automation toolto streamline the software release process, improving consistency and
# reducing manual effort.
# • Integrated release workflows withJiraandConfluencevia REST APIs and implementedunit testsfor 30+ release
# modules to ensure reliability.• Built cloud-basedCI/CD pipelineusing Azure DevOps and Azure CDN, cutting deployment time by50%and
# improving update availability.
# • Provisioned Azure infrastructure usingARM, implementing Infrastructure as Code (IaC) practices for repeatable and
# secure deployments.
# • Containerized release tools usingDockerto ensure environment consistency across development and deployment stages.
# • Optimized packaging and delivery workflows, achieving a40% reductionin software package size and a20%
# reductionin cloud operational costs.
# Bosch Thermotechnik / Bosch Home Comfort08/2022 - 01/2023
# DevOps Engineer Intern Wernau, Germany
# • Process Automation: Automated embedded software release tasks usingPythonand the BoschQG-CLItool,
# enabling consistent and repeatable artifact retrieval from multiple sources.
# • Developed Python scripts to integrate QG-CLI into aJenkins CI/CD pipeline, achieving a100% reduction in
# manual artifact fetch timeand improving release workflow reliability.
# • Enhanced internal tooling by identifying defects, reporting issues, and proposing improvements toQG-CLI, contributing
# to more stable release automation.
# Fraunhofer IOSB 08/2021 - 04/2022
# Research Assistant Ilmenau, Germany
# • Conducted comparative analysis of existing network simulators and simulation frameworks.
# • Simulation of different protocols for wireless communication using OMNeT++.
# • Utilized the data from firmware to create a simulation model using OMNeT++ that emulates the behavior of network
# nodes within the RTLS.
# • Implemented CI/CD pipeline to automatically test the software packages.
# GE Healthcare 07/2018 - 06/2019
# Manufacturing Process Trainee Engineer Bengaluru, India
# • Testing and Process Improvement: Implemented testing procedures for X-ray tube process equipment and supported
# product development.
# • Technical expert for (High kV Generator) product manufacturing processes, worked with value-stream team on daily and
# long-term projects impacting production, effectively participated in cross-functional kaizen events by learning and then
# utilising Lean concepts.
# • Supported development and evaluation of manufacturing processes for potential improvements and implementing change
# control procedures.
# Education
# Technical University of Ilmenau, Germany10/2019 - 07/2024
# Master of Science in Communications and Signal Processing Ilmenau, Germany
# Major Subjects: Communication Networks, Advanced Mobile Communication Networks, Cloud Computing.
# Collaborative research project: Cloud Security and DevSecOps Infrastructure for Machine Learning based IoT threat
# Mitigation. Automated DevSecOps CI/CD pipelines with integrated SAST and dependency, vulnerability scans to containerize
# and deploy the ML based threat detection service on Azure Kubernetes Service (AKS). Automated cloud resource provisioning
# using Terraform (IaC) and established observability with Prometheus and Grafana.
# Thesis: Investigation of Cloud-based Software Packaging and Release Management Systems at TeamViewer. Skills: Software
# Development Lifecycle, DevOps Practices, Microsoft Azure, Software Packaging and Deployment automation, CI/CD
# pipelines, Artifact Creation, Content Delivery Network (CDN).
# Visvesvaraya Technological University - RNSIT, India08/2014 - 06/2018
# Bachelor of Engineering in Electronics and Communication Bengaluru, India
# Thesis: Pest Control System using Raspberry pi
# Certifications
# Microsoft Certified: Azure Fundamentals|Atlassian Agile Project Management Professional Certificate|
# DevOps Professional Certificate by PagerDuty and LinkedIn|Docker Foundations Professional Certificate|
# Career Essentials in GitHub Professional Certificate|ISTQB Certified Tester Foundation Level (CTFL)|
# ISTQB Certified Tester – Testing with Generative AI (CT-GenAI) (Training Completed — Certification
# Examination Scheduled: Aug 2026)
# Language Skills
# German:A2 (Beginner)|English:Fluent (Professional Proficiency)
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi, I’m Guru Karthik’s digital twin — an AI representation of him for this website.
#
# Guru is originally from Bengaluru, India, and moved to Germany in 2019. He works as a Release Engineer with 4+ years of experience across connected systems, CI/CD pipelines, cloud platforms, automation, and software release management. His background is especially strong in automotive software, system integration, test automation, and secure software delivery.
#
# A few areas he’s worked on:
# - End-to-end system validation and Hardware-in-the-Loop testing
# - Python-based test and release automation
# - Jenkins, Azure DevOps, GitHub Actions, and CI/CD pipelines
# - Cloud and container technologies like Azure, Docker, Kubernetes, and Terraform
# - Automotive protocols and connectivity stacks, including CAN/CAN-FD, MQTT, REST, and TLS/mTLS
# - Trace, log, and defect analysis across distributed systems
#
# He’s also interested in applying AI-driven approaches and security testing to improve verification pipelines and software quality.
#
# Outside of work, he’s a foodie who especially likes vegetarian food, high-protein/high-fiber meals, South Indian food, and also enjoys North Indian cuisine. He likes sports too — cricket, badminton, calisthenics, and running.
#
# If you’d like, I can also give you a more detailed overview of his experience, skills, or recent projects.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])
# Out:
# 'Hi, I’m Guru Karthik’s digital twin — an AI representation of him for this website.\n\nI’m originally from Bengaluru, India, and moved to Germany in 2019. Professionally, I work as a Release Engineer / System Integration Test Engineer with 4+ years of experience in CI/CD, automation, cloud platforms, and software release management, with a strong focus on secure and reliable software delivery.\n\nMy background includes:\n- System integration and end-to-end testing\n- Release engineering and sprint-based release management\n- CI/CD automation with Jenkins, Azure DevOps, GitHub Actions\n- Python-based test and release tooling\n- Cloud and container technologies like Azure, Docker, Kubernetes, and Terraform\n- Automotive connectivity, HiL testing, and trace/log analysis\n- DevSecOps and software quality improvements\n\nOutside work, I’m a foodie — especially into vegetarian, high-protein, high-fiber food — and I really enjoy South Indian food. I also like sports such as cricket, badminton, calisthenics, and running.\n\nIf you’d like, I can also give you a short “elevator pitch” version of my background.'

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# gio: http://127.0.0.1:7861/: Operation not supported
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")
# Out:
# Tool called to record an email: test@testy.com
# 'Email received'

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# gio: http://127.0.0.1:7863/: Operation not supported

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# gio: http://127.0.0.1:7864/: Operation not supported

# %%
judge = f""""
You are judging a question from user and evaluate whether its completely related to what pupose it do.
and you should not respond the questions that are not relatable.
Also evaluate whether user giving the right information also inform them if they miss something that is worth mentioning. 
"""

# %%
judge_messages = [{"role": "system", "content": judge}]

# %%
model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=judge_messages)
results = response.choices[0].message.content
print(results)
# Out:
# I can do that. Please provide:
#
# - The question you want evaluated.
# - The intended purpose or goal of that question (i.e., what it should achieve).
#
# How I’ll evaluate (and what I’ll tell you):
# - Relevance: Is the question fully aligned with the stated purpose? I’ll mark it as fully related, partially related, or not related.
# - Information sufficiency: Does the user supply enough details for a proper answer? I’ll point out missing or important information if any.
# - Clarity and assumptions: I’ll flag any unclear terms or assumptions the question makes.
# - Guidance: If it’s related, I’ll suggest how to improve the question (be more specific, add required data, etc.) and what additional info would help.
#
# Note: If a question is not relatable to the stated purpose, I won’t provide an answer content for it and will explain why it’s not related.
#
# Please share the question and the purpose, and I’ll start.
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# Tool called to record an email: here is my email id note it
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# Tool called to record an email: thanushree@gmail.com
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)
# /home/thanu/projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   queue = blocks._queue.pending_messages_per_session.get(session_hash)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
